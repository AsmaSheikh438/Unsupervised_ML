# %% [markdown]
# ### UNSUPERVISED MACHINE LEARNING
# #### Unsupervised Learning is a type  of machine learning that learns from unlabeled data.
# * This means that the data does not have any pre-exixting labels or categories.
# * Unsupervised learning is helpful for finding useful insights from the data.
# * Unsupervised learning is much similar as a human learns to think by their own experiences, which makes it closer to the real AI.
# * Unsupervised learning works on unlabeled and uncategorized data which make unsupervised learning more important.
# * In real-world, we do not always have input data with the corresponding output so to solve such cases, we need unsupervised learning.
# * The goal  of Unsupervised learning is to discover patterns and relationships in the data without any explicit guidance.
# * Labeled data contain both input & output and Unlabeled data contain only input.

# %% [markdown]
# ![unsupervised-machine-learning-1.png (600×300) - Google Chrome 08-12-2024 12_51_54 (1).png](attachment:d9de4993-731f-4c46-993e-757de760e463.png)

# %% [markdown]
# ![unsupervised-machine-learning-1.png (600×300) - Google Chrome 08-12-2024 12_47_46.png](attachment:2684cdcc-93f8-4cb2-80ef-44d3687d86e3.png)

# %% [markdown]
# ![unsupervised-machine-learning-1.png (600×300) - Google Chrome 08-12-2024 12_49_20.png](attachment:2bdd071d-b627-447e-bb9c-8e8eb641f230.png)

# %% [markdown]
# ![unsupervised-machine-learning-1.png (600×300) - Google Chrome 08-12-2024 13_01_44.png](attachment:57307aee-3ebd-4450-8e87-1f7b8b75ccd6.png)

# %% [markdown]
# ![unsupervised-machine-learning-1.png (600×300) - Google Chrome 08-12-2024 13_04_51.png](attachment:d2a61c7f-b30b-4550-b9ac-e6ede896d616.png)

# %% [markdown]
# ![unsupervised-machine-learning-1.png (600×300) - Google Chrome 08-12-2024 13_07_40.png](attachment:6219ff11-3155-46f9-a5b0-071e20d65234.png)

# %% [markdown]
# ## Unsupervised Learning algorithms:

# %% [markdown]
# * K-means clustering
# * KNN (k-nearest neighbors)
# * Hierarchal clustering
# * Anomaly detection
# * Neural Networks
# * Principle Component Analysis
# * Independent Component Analysis
# * Apriori algorithm
# * Singular value decomposition

# %% [markdown]
# ## Advantages of Unsupervised Learning
# * Unsupervised learning is used for more complex tasks as compared to supervised learning because, in unsupervised learning, we don't have labeled input data.
# * Unsupervised learning is preferable as it is easy to get unlabeled data in comparison to labeled data.
# ## Disadvantages of Unsupervised Learning
# * Unsupervised learning is intrinsically more difficult than supervised learning as it does not have corresponding output.
# * The result of the unsupervised learning algorithm might be less accurate as input data is not labeled, and algorithms do not know the exact output in advance.
